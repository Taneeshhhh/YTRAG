# %% [markdown]
# ## Data ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text contian i am using to learn rag",
    metadata={
        "source":"example.txt",
        "page":1,
        "author":"Taneeeshh"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'page': 1, 'author': 'Taneeeshh'}, page_content='this is the main text contian i am using to learn rag')

# %%
import os 
os.makedirs("../data/text_files",exist_ok=True)
